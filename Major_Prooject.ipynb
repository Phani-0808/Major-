# %% [markdown]
# <a href="https://colab.research.google.com/github/Phani-0808/Major-/blob/main/Major_Prooject.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install vadersentiment
# Out:
# Collecting vadersentiment
#   Downloading https://files.pythonhosted.org/packages/76/fc/310e16254683c1ed35eeb97386986d6c00bc29df17ce280aed64d55537e9/vaderSentiment-3.3.2-py2.py3-none-any.whl (125kB)
#      |████████████████████████████████| 133kB 7.6MB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from vadersentiment) (2.23.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->vadersentiment) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->vadersentiment) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->vadersentiment) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->vadersentiment) (2020.12.5)
# Installing collected packages: vadersentiment
# Successfully installed vadersentiment-3.3.2

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
vs = SentimentIntensityAnalyzer()

# %%
text = "The product is really Awesome!!"
vs.polarity_scores(text)
# Out:
# {'compound': 0.7164, 'neg': 0.0, 'neu': 0.446, 'pos': 0.554}

# %%
text2 ="Amazing phone with great cameras and better battery which gives you the best performance. I just love the camera ."
vs.polarity_scores(text2)
# Out:
# {'compound': 0.9648, 'neg': 0.0, 'neu': 0.439, 'pos': 0.561}

# %%
text3="everything is fine except battery"
vs.polarity_scores(text3)
# Out:
# {'compound': 0.2023, 'neg': 0.0, 'neu': 0.69, 'pos': 0.31}

# %%
text4="we didn't learnt anything about ML"
vs.polarity_scores(text4)
# Out:
# {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0}

# %%
text5="it was not much interesting. that teacher was not compromising  so its was not too interesting"
vs.polarity_scores(text5)
# Out:
# {'compound': -0.5448, 'neg': 0.244, 'neu': 0.756, 'pos': 0.0}

# %%
# web scraping

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import os

# %%
# url = "https://inshorts.com/en/read/sports"
# news_data = []
# news_category = url.split("/")[-1]
# news_category

# %%
url = 'https://inshorts.com/en/read/sports'
news_data = []
news_category = url.split('/')[-1]
data = requests.get(url)
soup = BeautifulSoup(data.content)
print(soup)
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <style>
#     /* The Modal (background) */
#     .modal_contact {
#         display: none; /* Hidden by default */
#         position: fixed; /* Stay in place */
#         z-index: 8; /* Sit on top */
#         left: 0;
#         top: 0;
#         width: 100%; /* Full width */
#         height: 100%;
#         overflow: auto; /* Enable scroll if needed */
#         background-color: rgb(0,0,0); /* Fallback color */
#         background-color: rgba(0,0,0,0.4); /* Black w/ opacity */
#     }
#
#     /* Modal Content/Box */
#     .modal-content {
#         background-color: #fefefe;
#         margin: 15% auto;
#         padding: 20px !important;
#         padding-top: 0 !important;
#         /* border: 1px solid #888; */
#         text-align: center;
#         position: relative;
#         border-radius: 6px;
#     }
#
#     /* The Close Button */
#     .close {
#       left: 90%;
#       color: #aaa;
#       float: right;
#       font-size: 28px;
#       font-weight: bold;
#     /* position: absolute; */
#     /* bottom: 86%; */
#     /* display: inline-block; */
#     /* padding-left: 5%; */
#     }
#
#     .close:hover,
#     .close:focus {
#         color: black;
#         text-decoration: none;
#         cursor: pointer;
#     }
#
#     #myBtn {
#       background: #999999;
#       color: #ffffff;
#       text-transform: uppercase;
#       font-weight: bold;
#       box-shadow: none;
#       border-radius: 4px;
#       border: none;
#       font-size: .8rem;
#       /* width: 8rem; */
#       height: 2rem;
#       line-height: 2rem;
#     }
#
#     .contact {
#       margin-bottom: 4%;
#       clear: both;
#     }
#   </style>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="width=device-width, initial-scale=1, maximum-scale=1.0, user-scalable=no" name="viewport"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <link href="manifest.json" rel="manifest"/>
# <!-- Fallback to homescreen for Chrome   <39 on Android -->
# <meta content="yes" name="mobile-web-app-capable"/>
# <meta content="inshorts" name="application-name"/>
# <link href="https://assets.inshorts.com/website_assets/images/favicon.png" rel="icon" sizes="192x192"/>
# <!-- Add to homescreen for Safari on iOS -->
# <meta content="yes" name="apple-mobile-web-app-capable"/>
# <meta content="#424242" name="apple-mobile-web-app-status-bar-style"/>
# <meta content="inshorts" name="apple-mobile-web-app-title"/>
# <link href="https://assets.inshorts.com/website_assets/images/favicon.png" rel="apple-touch-icon"/>
# <!-- Tile icon for Win8 (144x144 + tile color) -->
# <meta content="fav/favicon.png" name="msapplication-TileImage"/>
# <meta content="#424242" name="msapplication-TileColor"/>
# <meta content="#424242" name="theme-color"/>
# <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
# <meta content="#424242" name="msapplication-navbutton-color"/>
# <meta content="#424242" name="apple-mobile-web-app-status-bar-style"/>
# <link href="https://assets.inshorts.com/website_assets/images/favicon.png" rel="apple-touch-startup-image"/>
# <meta content="black-translucent" name="apple-mobile-web-app-status-bar-style"/>
# <meta content="app" name="twitter:card"/>
# <meta content="@inshorts" name="twitter:site"/>
# <meta content="@inshorts" name="twitter:creator"/>
# <meta content="Inshorts delivers news in less than 60 words, containing only the essential facts, compromising on anything that is close to opinionating and storytelling." name="twitter:description"/>
# <meta content="IN" name="twitter:app:country"/>
# <meta content="Inshorts - Stay Informed" name="twitter:app:name:iphone"/>
# <meta content="892146527" name="twitter:app:id:iphone"/>
# <meta content="nis://news" name="twitter:app:url:iphone"/>
# <meta content="Inshorts - Stay Informed" name="twitter:app:name:ipad"/>
# <meta content="892146527" name="twitter:app:id:ipad"/>
# <meta content="nis://news" name="twitter:app:url:ipad"/>
# <meta content="Inshorts - Stay Informed" name="twitter:app:name:googleplay"/>
# <meta content="com.nis.app" name="twitter:app:id:googleplay"/>
# <meta content="nis://news" name="twitter:app:url:googleplay"/>
# <meta content="Read sports news in English in less that 60 words and get updated with latest cricket, football, tennis and basketball in a fast and easy way with inshorts." name="description"/>
# <link href="https://inshorts.com/en/read/sports" rel="canonical"/>
# <link href="https://inshorts.com/en/read/sports" reflang="en" rel="alternate"/>
# <meta content="app-id=892146527" name="apple-itunes-app"/>
# <meta content="app-id=com.nis.app" name="google-play-app"/>
# <title>Sports News: Cricket News, Football News &amp; Tennis News in English with Inshorts</title>
# <!-- CSS  -->
# <link href="https://fonts.googleapis.com/css?family=Roboto" rel="stylesheet" type="text/css"/>
# <link href="https://fonts.googleapis.com/icon?family=Material+Icons" rel="stylesheet"/>
# <link href="https://cdnjs.cloudflare.com/ajax/libs/materialize/0.97.1/css/materialize.min.css" rel="stylesheet"/>
# <link href="https://fonts.googleapis.com/css?family=Hind:500,600,400&amp;subset=latin,devanagari" rel="stylesheet" type="text/css"/>
# <link href="/dist/styles/main.css" media="screen,projection" rel="stylesheet" type="text/css"/>
# <link href="/dist/styles/index.css" media="screen,projection" rel="stylesheet" type="text/css"/>
# <link href="/dist/styles/read.css" media="screen,projection" rel="stylesheet" type="text/css"/>
# <link href="/dist/styles/news-card.css" media="screen,projection" rel="stylesheet" type="text/css"/>
# <link href="https://assets.inshorts.com/website_assets/images/favicon.png" rel="icon" type="image/png"/>
# <link href="/dist/manifest.json" rel="manifest"/>
# <script async="async" src="https://www.googletagservices.com/tag/js/gpt.js"></script>
# <script>
#     var googletag = googletag || {};
#     googletag.cmd = googletag.cmd || [];
#     let top_banner_slot;
#   </script>
# <!-- Top banner for desktop-->
# <script>
#     googletag.cmd.push(function() {
#
#
#         //Top banner for desktop
#         top_banner_slot = googletag.defineSlot('/142919096/inshorts_website_728x90', [728, 90], 'div-gpt-ad-1536585015617-0')
#         .addService(googletag.pubads())
#         .setCollapseEmptyDiv(true,true);
#
#
#       googletag.pubads().disableInitialLoad();
#       googletag.pubads().enableSingleRequest();
#       googletag.enableServices();
#     });
#   </script>
# <!-- Facebook Pixel Code -->
# <script>
#     !function(f,b,e,v,n,t,s)
#     {if(f.fbq)return;n=f.fbq=function(){n.callMethod?
#     n.callMethod.apply(n,arguments):n.queue.push(arguments)};
#     if(!f._fbq)f._fbq=n;n.push=n;n.loaded=!0;n.version='2.0';
#     n.queue=[];t=b.createElement(e);t.async=!0;
#     t.src=v;s=b.getElementsByTagName(e)[0];
#     s.parentNode.insertBefore(t,s)}(window, document,'script',
#     'https://connect.facebook.net/en_US/fbevents.js');
#     fbq('init', '822966517773327');
#     fbq('track', 'PageView');
#   </script>
# <noscript><img height="1" src="https://www.facebook.com/tr?id=822966517773327&amp;ev=PageView&amp;noscript=1" style="display:none" width="1"/></noscript>
# <!-- End Facebook Pixel Code -->
# </head>
# <script>
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-55157535-6', 'auto');
#   ga('send', 'pageview');
# </script>
# <body>
# <!-- Begin comScore Tag -->
# <script>
#     var _comscore = _comscore || [];
#     _comscore.push({ c1: "2", c2: "28268321" });
#     (function() {
#       var s = document.createElement("script"), el = document.getElementsByTagName("script")[0]; s.async = true;
#       s.src = (document.location.protocol == "https:" ? "https://sb" : "http://b") + ".scorecardresearch.com/beacon.js";
#       el.parentNode.insertBefore(s, el);
#     })();
#   </script>
# <noscript>
# <img src="https://sb.scorecardresearch.com/p?c1=2&amp;c2=28268321&amp;cv=2.0&amp;cj=1"/>
# </noscript>
# <!-- HEADER START -->
# <div class="header z-depth-1">
# <div class="menu clickable">
# <button class="c-hamburger c-hamburger--htx"><span>toggle menu</span></button><span class="unselectable">Menu</span>
# </div>
# <!--
#     <div class="search-wrapper hide-on-small-only">
#       <input class="search-box" placeholder="Search" id="search"/>
#       <i id="search_icon" class="material-icons search-icon">search</i>
#       <div class="search-box-ul">&nbsp;</div>
#     </div>
#     -->
# <a href="/"><img class="logo" src="https://assets.inshorts.com/website_assets/images/logo_inshorts.png"/></a>
# </div>
# <!-- HEADER END -->
# <!--SIDEBAR START -->
# <div class="hide-on-med-and-up sidebar-bg" style="display: none;"> </div>
# <div class="sidebar" style="overflow-y: scroll;">
# <div class="lang-bar" style="">
# <div class="lang-selector clickable">
# <a href="/en/read/sports"><div class="lang-en selected">English</div></a>
# <a href="/hi/read/sports"><div class="lang-hi ">हिन्दी</div></a>
# </div>
# </div>
# <div>
# <div class="category-header">Categories</div>
# <ul class="category-list">
# <a href="/en/read" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'LinkToAllNews', 'eventAction': 'clicked', 'eventLabel': 'RedirectedToAllNews' });"> <li class="active-category ">All News</li> </a>
# <a href="/en/read/national" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'LinkToIndiaNews', 'eventAction': 'clicked', 'eventLabel': 'RedirectedToIndiaNews' });"> <li class="active-category ">India</li> </a>
# <a href="/en/read/business" onclick="ga(" send=""> <li class="active-category ">Business</li> </a>
# <a href="/en/read/sports" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'LinkTosportsNews', 'eventAction': 'clicked', 'eventLabel': 'RedirectedToSportsNews' });"> <li class="active-category selected">Sports</li> </a>
# <a href="/en/read/world" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'LinkToworldNews', 'eventAction': 'clicked', 'eventLabel': 'RedirectedToworldNews' });"> <li class="active-category ">World</li> </a>
# <a href="/en/read/politics" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'LinkToworldNews', 'eventAction': 'clicked',   'eventLabel': 'RedirectedToworldNews' });"> <li class="active-category ">Politics</li> </a>
# <a href="/en/read/technology" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'LinkTotechnologyNews', 'eventAction': 'clicked', 'eventLabel': 'RedirectedTotechnologyNews' });"> <li class="active-category ">Technology</li> </a>
# <a href="/en/read/startup" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'LinkTostartupNews', 'eventAction': 'clicked', 'eventLabel': 'RedirectedTostartupNews' });"> <li class="active-category ">Startup</li> </a>
# <a href="/en/read/entertainment" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'LinkToEntertainmentNews', 'eventAction': 'clicked', 'eventLabel': 'RedirectedToEntertainmentNews' });"> <li class="active-category ">Entertainment</li> </a>
# <a href="/en/read/miscellaneous" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'LinkToMiscellaneousNews', 'eventAction': 'clicked', 'eventLabel': 'RedirectedToMiscellaneousNews' });"> <li class="active-category ">Miscellaneous</li> </a>
# <a href="/en/read/hatke" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'LinkTohatkeNews', 'eventAction': 'clicked', 'eventLabel': 'RedirectedTohatkeNews' });"> <li class="active-category ">Hatke</li> </a>
# <a href="/en/read/science" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'LinkToscienceNews', 'eventAction': 'clicked', 'eventLabel': 'RedirectedToscienceNews' });"> <li class="active-category ">Science</li> </a>
# <a href="/en/read/automobile" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'LinkToautomobileNews', 'eventAction': 'clicked', 'eventLabel': 'RedirectedToautomobileNews' });"> <li class="active-category ">Automobile</li> </a>
# </ul>
# </div>
# </div>
# <!--SIDEBAR END -->
# <!-- BODY START -->
# <div class="container" style="min-height:550px;">
# <div class="row" style="padding-top:110px;">
# <div id="div-gpt-ad-1536585015617-0" style="height:90px; width:728px;margin: auto; margin-bottom: 1%;">
# <script>
#           googletag.cmd.push(function() {
#             googletag.display('div-gpt-ad-1536585015617-0');
#             googletag.pubads().refresh([top_banner_slot]);
#           });
#           </script>
# </div>
# <div class="hide-on-med-and-down z-depth-1" style="margin-left : auto;margin-right : auto;margin-bottom: 32px;width : 900px;height:48px;background: #f44336">
# <div style="font-weight: 300;color:white !important;font-size:14px;margin-left: 48px;margin-top: 13px;position: absolute;display: block;">
#           For the best experience use <a href="https://inshorts.com/mobile" style="color:white;appearance: none;font-weight: 500;" target="_blank">inshorts</a> app on your smartphone
#         </div>
# </div>
# <div class="card-stack">
# <div class="">
# <div class="news-card z-depth-1" itemscope="" itemtype="http://schema.org/NewsArticle">
# <span content="" itemid="https://inshorts.com/en/news/picture-of-dwayne-bravo-stealing-a-run-goes-viral-prompts-mankading-debate-1618897998360" itemprop="mainEntityOfPage" itemscope="" itemtype="https://schema.org/WebPage"></span>
# <span itemprop="author" itemscope="itemscope" itemtype="https://schema.org/Person">
# <span content="Anmol Sharma" itemprop="name"></span>
# </span>
# <span content="Picture of Dwayne Bravo 'stealing' a run goes viral, prompts 'mankading' debate" itemprop="description"></span>
# <span itemprop="image" itemscope="" itemtype="https://schema.org/ImageObject">
# <meta content="https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2021/04_apr/20_tue/img_1618897106311_958.jpg?" itemprop="url"/>
# <meta content="864" itemprop="width"/>
# <meta content="483" itemprop="height"/>
# </span>
# <span itemprop="publisher" itemscope="itemscope" itemtype="https://schema.org/Organization">
# <span content="https://inshorts.com/" itemprop="url"></span>
# <span content="Inshorts" itemprop="name"></span>
# <span itemprop="logo" itemscope="" itemtype="https://schema.org/ImageObject">
# <span content="https://assets.inshorts.com/inshorts/images/v1/variants/jpg/m/2018/11_nov/21_wed/img_1542823931298_497.jpg" itemprop="url"></span>
# <meta content="400" itemprop="width"/>
# <meta content="60" itemprop="height"/>
# </span>
# </span>
# <div class="news-card-image" style="background-image: url('https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2021/04_apr/20_tue/img_1618897106311_958.jpg?')">
# </div>
# <div class="news-card-title news-right-box">
# <a class="clickable" href="/en/news/picture-of-dwayne-bravo-stealing-a-run-goes-viral-prompts-mankading-debate-1618897998360" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'TitleOfNews', 'eventAction': 'clicked', 'eventLabel': 'Picture%20of%20Dwayne%20Bravo%20'stealing'%20a%20run%20goes%20viral%2C%20prompts%20'mankading'%20debate)' });" style="color:#44444d!important">
# <span itemprop="headline">Picture of Dwayne Bravo 'stealing' a run goes viral, prompts 'mankading' debate</span>
# </a>
# <div class="news-card-author-time news-card-author-time-in-title">
# <a href="/prev/en/news/picture-of-dwayne-bravo-stealing-a-run-goes-viral-prompts-mankading-debate-1618897998360"><span class="short">short</span></a> by <span class="author">Anmol Sharma</span> /
#       <span class="time" content="2021-04-20T05:53:18.000Z" itemprop="datePublished">11:23 am</span> on <span clas="date">20 Apr 2021,Tuesday</span>
# </div>
# </div>
# <div class="news-card-content news-right-box">
# <div itemprop="articleBody">A picture of CSK's Dwayne Bravo being way out of his crease at the non-striker's end even before RR's Mustafizur Rahman had bowled a delivery has gone viral. Commentator Harsha Bhogle opined that mankading should be encouraged in such cases. "All this talk about not being in the spirit of the game is so much nonsense," he said.</div>
# <div class="news-card-author-time news-card-author-time-in-content">
# <a href="/prev/en/news/picture-of-dwayne-bravo-stealing-a-run-goes-viral-prompts-mankading-debate-1618897998360"><span class="short">short</span></a> by <span class="author">Anmol Sharma</span> /
#       <span class="time" content="2021-04-20T05:53:18.000Z" itemprop="dateModified">11:23 am</span> on <span class="date">20 Apr</span>
# </div>
# </div>
# <div class="news-card-footer news-right-box">
# <div class="read-more">read more at <a class="source" href="https://www.crictracker.com/ipl-2021-harsha-bhogle-calls-for-mankading-to-be-made-mandatory/?amp=&amp;utm_campaign=fullarticle&amp;utm_medium=referral&amp;utm_source=inshorts " onclick="ga('send', {'hitType': 'event', 'eventCategory': 'ReadMore', 'eventAction': 'clicked', 'eventLabel': 'CricTracker' });" target="_blank">CricTracker</a></div>
# </div>
# </div>
# </div>
# <div class="">
# <div class="news-card z-depth-1" itemscope="" itemtype="http://schema.org/NewsArticle">
# <span content="" itemid="https://inshorts.com/en/news/csk-mark-dhonis-200th-match-as-their-captain-with-45run-win-over-rr-1618855040083" itemprop="mainEntityOfPage" itemscope="" itemtype="https://schema.org/WebPage"></span>
# <span itemprop="author" itemscope="itemscope" itemtype="https://schema.org/Person">
# <span content="Anmol Sharma" itemprop="name"></span>
# </span>
# <span content="CSK mark Dhoni's 200th match as their captain with 45-run win over RR" itemprop="description"></span>
# <span itemprop="image" itemscope="" itemtype="https://schema.org/ImageObject">
# <meta content="https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2021/04_apr/19_mon/img_1618854717398_634.jpg?" itemprop="url"/>
# <meta content="864" itemprop="width"/>
# <meta content="483" itemprop="height"/>
# </span>
# <span itemprop="publisher" itemscope="itemscope" itemtype="https://schema.org/Organization">
# <span content="https://inshorts.com/" itemprop="url"></span>
# <span content="Inshorts" itemprop="name"></span>
# <span itemprop="logo" itemscope="" itemtype="https://schema.org/ImageObject">
# <span content="https://assets.inshorts.com/inshorts/images/v1/variants/jpg/m/2018/11_nov/21_wed/img_1542823931298_497.jpg" itemprop="url"></span>
# <meta content="400" itemprop="width"/>
# <meta content="60" itemprop="height"/>
# </span>
# </span>
# <div class="news-card-image" style="background-image: url('https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2021/04_apr/19_mon/img_1618854717398_634.jpg?')">
# </div>
# <div class="news-card-title news-right-box">
# <a class="clickable" href="/en/news/csk-mark-dhonis-200th-match-as-their-captain-with-45run-win-over-rr-1618855040083" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'TitleOfNews', 'eventAction': 'clicked', 'eventLabel': 'CSK%20mark%20Dhoni's%20200th%20match%20as%20their%20captain%20with%2045-run%20win%20over%20RR)' });" style="color:#44444d!important">
# <span itemprop="headline">CSK mark Dhoni's 200th match as their captain with 45-run win over RR</span>
# </a>
# <div class="news-card-author-time news-card-author-time-in-title">
# <a href="/prev/en/news/csk-mark-dhonis-200th-match-as-their-captain-with-45run-win-over-rr-1618855040083"><span class="short">short</span></a> by <span class="author">Anmol Sharma</span> /
#       <span class="time" content="2021-04-19T17:57:20.000Z" itemprop="datePublished">11:27 pm</span> on <span clas="date">19 Apr 2021,Monday</span>
# </div>
# </div>
# <div class="news-card-content news-right-box">
# <div itemprop="articleBody">Chennai Super Kings defeated Rajasthan Royals by 45 runs to register their second consecutive win in IPL 2021. The match was MS Dhoni's 200th as the captain of CSK. CSK are now on the second position on the points table, while Rajasthan Royals are placed sixth. CSK all-rounder Ravindra Jadeja took two wickets and four catches in the match.</div>
# <div class="news-card-author-time news-card-author-time-in-content">
# <a href="/prev/en/news/csk-mark-dhonis-200th-match-as-their-captain-with-45run-win-over-rr-1618855040083"><span class="short">short</span></a> by <span class="author">Anmol Sharma</span> /
#       <span class="time" content="2021-04-19T17:57:20.000Z" itemprop="dateModified">11:27 pm</span> on <span class="date">19 Apr</span>
# </div>
# </div>
# <div class="news-card-footer news-right-box">
# <div class="read-more">read more at <a class="source" href="https://www.cricketcountry.com/series/indian-premier-league-2021-201824/live-scores/-vs--live-cricket-score-match-12-201008-summary.html?utm_campaign=fullarticle&amp;utm_medium=referral&amp;utm_source=inshorts " onclick="ga('send', {'hitType': 'event', 'eventCategory': 'ReadMore', 'eventAction': 'clicked', 'eventLabel': 'Cricket%20Country' });" target="_blank">Cricket Country</a></div>
# </div>
# </div>
# </div>
# <div class="">
# <div class="news-card z-depth-1" itemscope="" itemtype="http://schema.org/NewsArticle">
# <span content="" itemid="https://inshorts.com/en/news/ms-dhonis-8yearold-tweet-resurfaces-after-jadeja-takes-4-catches-in-an-ipl-match-1618888846887" itemprop="mainEntityOfPage" itemscope="" itemtype="https://schema.org/WebPage"></span>
# <span itemprop="author" itemscope="itemscope" itemtype="https://schema.org/Person">
# <span content="Anmol Sharma" itemprop="name"></span>
# </span>
# <span content="MS Dhoni's 8-year-old tweet resurfaces after Jadeja takes 4 catches in an IPL match" itemprop="description"></span>
# <span itemprop="image" itemscope="" itemtype="https://schema.org/ImageObject">
# <meta content="https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2021/04_apr/20_tue/img_1618888109192_243.jpg?" itemprop="url"/>
# <meta content="864" itemprop="width"/>
# <meta content="483" itemprop="height"/>
# </span>
# <span itemprop="publisher" itemscope="itemscope" itemtype="https://schema.org/Organization">
# <span content="https://inshorts.com/" itemprop="url"></span>
# <span content="Inshorts" itemprop="name"></span>
# <span itemprop="logo" itemscope="" itemtype="https://schema.org/ImageObject">
# <span content="https://assets.inshorts.com/inshorts/images/v1/variants/jpg/m/2018/11_nov/21_wed/img_1542823931298_497.jpg" itemprop="url"></span>
# <meta content="400" itemprop="width"/>
# <meta content="60" itemprop="height"/>
# </span>
# </span>
# <div class="news-card-image" style="background-image: url('https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2021/04_apr/20_tue/img_1618888109192_243.jpg?')">
# </div>
# <div class="news-card-title news-right-box">
# <a class="clickable" href="/en/news/ms-dhonis-8yearold-tweet-resurfaces-after-jadeja-takes-4-catches-in-an-ipl-match-1618888846887" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'TitleOfNews', 'eventAction': 'clicked', 'eventLabel': 'MS%20Dhoni's%208-year-old%20tweet%20resurfaces%20after%20Jadeja%20takes%204%20catches%20in%20an%20IPL%20match)' });" style="color:#44444d!important">
# <span itemprop="headline">MS Dhoni's 8-year-old tweet resurfaces after Jadeja takes 4 catches in an IPL match</span>
# </a>
# <div class="news-card-author-time news-card-author-time-in-title">
# <a href="/prev/en/news/ms-dhonis-8yearold-tweet-resurfaces-after-jadeja-takes-4-catches-in-an-ipl-match-1618888846887"><span class="short">short</span></a> by <span class="author">Anmol Sharma</span> /
#       <span class="time" content="2021-04-20T03:20:46.000Z" itemprop="datePublished">08:50 am</span> on <span clas="date">20 Apr 2021,Tuesday</span>
# </div>
# </div>
# <div class="news-card-content news-right-box">
# <div itemprop="articleBody">After CSK all-rounder Ravindra Jadeja took four catches against Rajasthan Royals, captain MS Dhoni's eight-year-old tweet on Jadeja's fielding resurfaced and went viral. The tweet dated April 9, 2013 reads, "Sir Jadeja doesn't run to take the catch but the ball finds him and lands on his hand." A fan commented, "Eight years later, the fact still holds true."</div>
# <div class="news-card-author-time news-card-author-time-in-content">
# <a href="/prev/en/news/ms-dhonis-8yearold-tweet-resurfaces-after-jadeja-takes-4-catches-in-an-ipl-match-1618888846887"><span class="short">short</span></a> by <span class="author">Anmol Sharma</span> /
#       <span class="time" content="2021-04-20T03:20:46.000Z" itemprop="dateModified">08:50 am</span> on <span class="date">20 Apr</span>
# </div>
# </div>
# <div class="news-card-footer news-right-box">
# <div class="read-more">read more at <a class="source" href="https://www.instagram.com/p/CN21FSFniOj/?utm_campaign=fullarticle&amp;utm_medium=referral&amp;utm_source=inshorts " onclick="ga('send', {'hitType': 'event', 'eventCategory': 'ReadMore', 'eventAction': 'clicked', 'eventLabel': 'Instagram' });" target="_blank">Instagram</a></div>
# </div>
# </div>
# </div>
# <div class="">
# <div class="news-card z-depth-1" itemscope="" itemtype="http://schema.org/NewsArticle">
# <span content="" itemid="https://inshorts.com/en/news/cant-guarantee-performances-at-40-but-dont-want-anyone-to-say-i-am-unfit-dhoni-1618893556433" itemprop="mainEntityOfPage" itemscope="" itemtype="https://schema.org/WebPage"></span>
# <span itemprop="author" itemscope="itemscope" itemtype="https://schema.org/Person">
# <span content="Anmol Sharma" itemprop="name"></span>
# </span>
# <span content="Can't guarantee performances at 40 but don't want anyone to say I am unfit: Dhoni" itemprop="description"></span>
# <span itemprop="image" itemscope="" itemtype="https://schema.org/ImageObject">
# <meta content="https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2021/04_apr/20_tue/img_1618892913642_62.jpg?" itemprop="url"/>
# <meta content="864" itemprop="width"/>
# <meta content="483" itemprop="height"/>
# </span>
# <span itemprop="publisher" itemscope="itemscope" itemtype="https://schema.org/Organization">
# <span content="https://inshorts.com/" itemprop="url"></span>
# <span content="Inshorts" itemprop="name"></span>
# <span itemprop="logo" itemscope="" itemtype="https://schema.org/ImageObject">
# <span content="https://assets.inshorts.com/inshorts/images/v1/variants/jpg/m/2018/11_nov/21_wed/img_1542823931298_497.jpg" itemprop="url"></span>
# <meta content="400" itemprop="width"/>
# <meta content="60" itemprop="height"/>
# </span>
# </span>
# <div class="news-card-image" style="background-image: url('https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2021/04_apr/20_tue/img_1618892913642_62.jpg?')">
# </div>
# <div class="news-card-title news-right-box">
# <a class="clickable" href="/en/news/cant-guarantee-performances-at-40-but-dont-want-anyone-to-say-i-am-unfit-dhoni-1618893556433" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'TitleOfNews', 'eventAction': 'clicked', 'eventLabel': 'Can't%20guarantee%20performances%20at%2040%20but%20don't%20want%20anyone%20to%20say%20I%20am%20unfit%3A%20Dhoni)' });" style="color:#44444d!important">
# <span itemprop="headline">Can't guarantee performances at 40 but don't want anyone to say I am unfit: Dhoni</span>
# </a>
# <div class="news-card-author-time news-card-author-time-in-title">
# <a href="/prev/en/news/cant-guarantee-performances-at-40-but-dont-want-anyone-to-say-i-am-unfit-dhoni-1618893556433"><span class="short">short</span></a> by <span class="author">Anmol Sharma</span> /
#       <span class="time" content="2021-04-20T04:39:16.000Z" itemprop="datePublished">10:09 am</span> on <span clas="date">20 Apr 2021,Tuesday</span>
# </div>
# </div>
# <div class="news-card-content news-right-box">
# <div itemprop="articleBody">Following CSK's 45-run win over RR, captain MS Dhoni said, "When you're playing, you don't really want anyone to say he's unfit." He added, "I wasn't guaranteeing performances when I was 24, I can't guarantee when I'm 40, but at least if people can't point finger at me that he's unfit then that will be a big positive for me."</div>
# <div class="news-card-author-time news-card-author-time-in-content">
# <a href="/prev/en/news/cant-guarantee-performances-at-40-but-dont-want-anyone-to-say-i-am-unfit-dhoni-1618893556433"><span class="short">short</span></a> by <span class="author">Anmol Sharma</span> /
#       <span class="time" content="2021-04-20T04:39:16.000Z" itemprop="dateModified">10:09 am</span> on <span class="date">20 Apr</span>
# </div>
# </div>
# <div class="news-card-footer news-right-box">
# <div class="read-more">read more at <a class="source" href="https://www.crictracker.com/ipl-2021-match-12-csk-vs-rr-who-said-what/?amp=&amp;utm_campaign=fullarticle&amp;utm_medium=referral&amp;utm_source=inshorts " onclick="ga('send', {'hitType': 'event', 'eventCategory': 'ReadMore', 'eventAction': 'clicked', 'eventLabel': 'CricTracker' });" target="_blank">CricTracker</a></div>
# </div>
# </div>
# </div>
# <div id="div-gpt-ad-1536748319959-vw2zuzhb-1" style="height:250px; width:900px; margin: auto; margin-bottom: 2%;">
# <script>
#         googletag.cmd.push(function() {
#           //News banner for desktop
#           var slotIdWeb = 'div-gpt-ad-1536748319959-vw2zuzhb-1';
#           var slot = googletag.defineSlot('/142919096/inshorts_website_900x250', [900, 250], slotIdWeb)
#           .addService(googletag.pubads())
#           .setCollapseEmptyDiv(true,true);
#
#           googletag.display('div-gpt-ad-1536748319959-vw2zuzhb-1');
#           googletag.pubads().refresh([slot]);
#         });
#       </script>
# </div>
# <div class="">
# <div class="news-card z-depth-1" itemscope="" itemtype="http://schema.org/NewsArticle">
# <span content="" itemid="https://inshorts.com/en/news/ravindra-jadejas-call-me-celebration-after-taking-4-catches-against-rr-goes-viral-1618888662495" itemprop="mainEntityOfPage" itemscope="" itemtype="https://schema.org/WebPage"></span>
# <span itemprop="author" itemscope="itemscope" itemtype="https://schema.org/Person">
# <span content="Anmol Sharma" itemprop="name"></span>
# </span>
# <span content="Ravindra Jadeja's 'call me' celebration after taking 4 catches against RR goes viral" itemprop="description"></span>
# <span itemprop="image" itemscope="" itemtype="https://schema.org/ImageObject">
# <meta content="https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2021/04_apr/20_tue/img_1618887565788_262.jpg?" itemprop="url"/>
# <meta content="864" itemprop="width"/>
# <meta content="483" itemprop="height"/>
# </span>
# <span itemprop="publisher" itemscope="itemscope" itemtype="https://schema.org/Organization">
# <span content="https://inshorts.com/" itemprop="url"></span>
# <span content="Inshorts" itemprop="name"></span>
# <span itemprop="logo" itemscope="" itemtype="https://schema.org/ImageObject">
# <span content="https://assets.inshorts.com/inshorts/images/v1/variants/jpg/m/2018/11_nov/21_wed/img_1542823931298_497.jpg" itemprop="url"></span>
# <meta content="400" itemprop="width"/>
# <meta content="60" itemprop="height"/>
# </span>
# </span>
# <div class="news-card-image" style="background-image: url('https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2021/04_apr/20_tue/img_1618887565788_262.jpg?')">
# </div>
# <div class="news-card-title news-right-box">
# <a class="clickable" href="/en/news/ravindra-jadejas-call-me-celebration-after-taking-4-catches-against-rr-goes-viral-1618888662495" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'TitleOfNews', 'eventAction': 'clicked', 'eventLabel': 'Ravindra%20Jadeja's%20'call%20me'%20celebration%20after%20taking%204%20catches%20against%20RR%20goes%20viral)' });" style="color:#44444d!important">
# <span itemprop="headline">Ravindra Jadeja's 'call me' celebration after taking 4 catches against RR goes viral</span>
# </a>
# <div class="news-card-author-time news-card-author-time-in-title">
# <a href="/prev/en/news/ravindra-jadejas-call-me-celebration-after-taking-4-catches-against-rr-goes-viral-1618888662495"><span class="short">short</span></a> by <span class="author">Anmol Sharma</span> /
#       <span class="time" content="2021-04-20T03:17:42.000Z" itemprop="datePublished">08:47 am</span> on <span clas="date">20 Apr 2021,Tuesday</span>
# </div>
# </div>
# <div class="news-card-content news-right-box">
# <div itemprop="articleBody">CSK all-rounder Ravindra Jadeja celebrated taking four catches against RR in their IPL 2021 match on Monday by gesturing four through his fingers before doing a "call me" action. Reacting to the viral celebration, a fan tweeted, "Sir Jadeja is everywhere." Another wrote, "Jadeja calling BCCI to add him to A+ contract." Another wrote, "This guy is something else."</div>
# <div class="news-card-author-time news-card-author-time-in-content">
# <a href="/prev/en/news/ravindra-jadejas-call-me-celebration-after-taking-4-catches-against-rr-goes-viral-1618888662495"><span class="short">short</span></a> by <span class="author">Anmol Sharma</span> /
#       <span class="time" content="2021-04-20T03:17:42.000Z" itemprop="dateModified">08:47 am</span> on <span class="date">20 Apr</span>
# </div>
# </div>
# <div class="news-card-footer news-right-box">
# <div class="read-more">read more at <a class="source" href="https://www.sportskeeda.com/amp/cricket/news-ipl-2021-watch-ravindra-jadeja-s-special-celebration-taking-4-catches-goes-viral?utm_campaign=fullarticle&amp;utm_medium=referral&amp;utm_source=inshorts " onclick="ga('send', {'hitType': 'event', 'eventCategory': 'ReadMore', 'eventAction': 'clicked', 'eventLabel': 'Sportskeeda' });" target="_blank">Sportskeeda</a></div>
# </div>
# </div>
# </div>
# <div class="">
# <div class="news-card z-depth-1" itemscope="" itemtype="http://schema.org/NewsArticle">
# <span content="" itemid="https://inshorts.com/en/news/sanju-samson-collects-coin-again-after-winning-toss-against-ms-dhoni-pic-goes-viral-1618846909425" itemprop="mainEntityOfPage" itemscope="" itemtype="https://schema.org/WebPage"></span>
# <span itemprop="author" itemscope="itemscope" itemtype="https://schema.org/Person">
# <span content="Anmol Sharma" itemprop="name"></span>
# </span>
# <span content="Sanju Samson collects coin again after winning toss against MS Dhoni, pic goes viral" itemprop="description"></span>
# <span itemprop="image" itemscope="" itemtype="https://schema.org/ImageObject">
# <meta content="https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2021/04_apr/19_mon/img_1618845006852_698.jpg?" itemprop="url"/>
# <meta content="864" itemprop="width"/>
# <meta content="483" itemprop="height"/>
# </span>
# <span itemprop="publisher" itemscope="itemscope" itemtype="https://schema.org/Organization">
# <span content="https://inshorts.com/" itemprop="url"></span>
# <span content="Inshorts" itemprop="name"></span>
# <span itemprop="logo" itemscope="" itemtype="https://schema.org/ImageObject">
# <span content="https://assets.inshorts.com/inshorts/images/v1/variants/jpg/m/2018/11_nov/21_wed/img_1542823931298_497.jpg" itemprop="url"></span>
# <meta content="400" itemprop="width"/>
# <meta content="60" itemprop="height"/>
# </span>
# </span>
# <div class="news-card-image" style="background-image: url('https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2021/04_apr/19_mon/img_1618845006852_698.jpg?')">
# </div>
# <div class="news-card-title news-right-box">
# <a class="clickable" href="/en/news/sanju-samson-collects-coin-again-after-winning-toss-against-ms-dhoni-pic-goes-viral-1618846909425" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'TitleOfNews', 'eventAction': 'clicked', 'eventLabel': 'Sanju%20Samson%20collects%20coin%20again%20after%20winning%20toss%20against%20MS%20Dhoni%2C%20pic%20goes%20viral)' });" style="color:#44444d!important">
# <span itemprop="headline">Sanju Samson collects coin again after winning toss against MS Dhoni, pic goes viral</span>
# </a>
# <div class="news-card-author-time news-card-author-time-in-title">
# <a href="/prev/en/news/sanju-samson-collects-coin-again-after-winning-toss-against-ms-dhoni-pic-goes-viral-1618846909425"><span class="short">short</span></a> by <span class="author">Anmol Sharma</span> /
#       <span class="time" content="2021-04-19T15:41:49.000Z" itemprop="datePublished">09:11 pm</span> on <span clas="date">19 Apr 2021,Monday</span>
# </div>
# </div>
# <div class="news-card-content news-right-box">
# <div itemprop="articleBody">Ahead of the RR-CSK match in IPL 2021, RR captain Sanju Samson collected the coin from the ground and kept it after winning the toss against CSK captain MS Dhoni. The 26-year-old had also kept the coin in the pocket after winning the toss in his first-ever match as IPL captain on April 12.</div>
# <div class="news-card-author-time news-card-author-time-in-content">
# <a href="/prev/en/news/sanju-samson-collects-coin-again-after-winning-toss-against-ms-dhoni-pic-goes-viral-1618846909425"><span class="short">short</span></a> by <span class="author">Anmol Sharma</span> /
#       <span class="time" content="2021-04-19T15:41:49.000Z" itemprop="dateModified">09:11 pm</span> on <span class="date">19 Apr</span>
# </div>
# </div>
# <div class="news-card-footer news-right-box">
# <div class="read-more">read more at <a class="source" href="https://www.crictracker.com/ipl-2021-rajasthan-royals-captain-sanju-samson-keeps-the-toss-coin-with-him-yet-again/?amp=&amp;utm_campaign=fullarticle&amp;utm_medium=referral&amp;utm_source=inshorts " onclick="ga('send', {'hitType': 'event', 'eventCategory': 'ReadMore', 'eventAction': 'clicked', 'eventLabel': 'CricTracker' });" target="_blank">CricTracker</a></div>
# </div>
# </div>
# </div>
# <div class="">
# <div class="news-card z-depth-1" itemscope="" itemtype="http://schema.org/NewsArticle">
# <span content="" itemid="https://inshorts.com/en/news/sls-lokuhettige-banned-for-8-years-for-matchfixing-during-2017-t10-league-1618848593400" itemprop="mainEntityOfPage" itemscope="" itemtype="https://schema.org/WebPage"></span>
# <span itemprop="author" itemscope="itemscope" itemtype="https://schema.org/Person">
# <span content="Ankur Taliyan" itemprop="name"></span>
# </span>
# <span content="SL's Lokuhettige banned for 8 years for match-fixing during 2017 T10 League" itemprop="description"></span>
# <span itemprop="image" itemscope="" itemtype="https://schema.org/ImageObject">
# <meta content="https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2021/04_apr/19_mon/img_1618843436734_90.jpg?" itemprop="url"/>
# <meta content="864" itemprop="width"/>
# <meta content="483" itemprop="height"/>
# </span>
# <span itemprop="publisher" itemscope="itemscope" itemtype="https://schema.org/Organization">
# <span content="https://inshorts.com/" itemprop="url"></span>
# <span content="Inshorts" itemprop="name"></span>
# <span itemprop="logo" itemscope="" itemtype="https://schema.org/ImageObject">
# <span content="https://assets.inshorts.com/inshorts/images/v1/variants/jpg/m/2018/11_nov/21_wed/img_1542823931298_497.jpg" itemprop="url"></span>
# <meta content="400" itemprop="width"/>
# <meta content="60" itemprop="height"/>
# </span>
# </span>
# <div class="news-card-image" style="background-image: url('https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2021/04_apr/19_mon/img_1618843436734_90.jpg?')">
# </div>
# <div class="news-card-title news-right-box">
# <a class="clickable" href="/en/news/sls-lokuhettige-banned-for-8-years-for-matchfixing-during-2017-t10-league-1618848593400" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'TitleOfNews', 'eventAction': 'clicked', 'eventLabel': 'SL's%20Lokuhettige%20banned%20for%208%20years%20for%20match-fixing%20during%202017%20T10%20League)' });" style="color:#44444d!important">
# <span itemprop="headline">SL's Lokuhettige banned for 8 years for match-fixing during 2017 T10 League</span>
# </a>
# <div class="news-card-author-time news-card-author-time-in-title">
# <a href="/prev/en/news/sls-lokuhettige-banned-for-8-years-for-matchfixing-during-2017-t10-league-1618848593400"><span class="short">short</span></a> by <span class="author">Ankur Taliyan</span> /
#       <span class="time" content="2021-04-19T16:09:53.000Z" itemprop="datePublished">09:39 pm</span> on <span clas="date">19 Apr 2021,Monday</span>
# </div>
# </div>
# <div class="news-card-content news-right-box">
# <div itemprop="articleBody">Ex-Sri Lanka cricketer Dilhara Lokuhettige has been banned from all cricket for eight years after he was found guilty of three offences, including match-fixing, by an independent Anti-Corruption Tribunal. Lokuhettige was initially charged by Emirates Cricket Board over corruption during the inaugural session of the T10 tournament in Sharjah. Lokuhettige played nine ODIs and two T20Is for SL.</div>
# <div class="news-card-author-time news-card-author-time-in-content">
# <a href="/prev/en/news/sls-lokuhettige-banned-for-8-years-for-matchfixing-during-2017-t10-league-1618848593400"><span class="short">short</span></a> by <span class="author">Ankur Taliyan</span> /
#       <span class="time" content="2021-04-19T16:09:53.000Z" itemprop="dateModified">09:39 pm</span> on <span class="date">19 Apr</span>
# </div>
# </div>
# <div class="news-card-footer news-right-box">
# <div class="read-more">read more at <a class="source" href="https://www.crictracker.com/sri-lankas-dilhara-lokuhettige-banned-for-eight-years-under-icc-anti-corruption-code/?amp=&amp;utm_campaign=fullarticle&amp;utm_medium=referral&amp;utm_source=inshorts " onclick="ga('send', {'hitType': 'event', 'eventCategory': 'ReadMore', 'eventAction': 'clicked', 'eventLabel': 'CricTracker' });" target="_blank">CricTracker</a></div>
# </div>
# </div>
# </div>
# <div class="">
# <div class="news-card z-depth-1" itemscope="" itemtype="http://schema.org/NewsArticle">
# <span content="" itemid="https://inshorts.com/en/news/moeen-ali-is-on-fire-hes-enjoying-batting-at-the-top-curran-1618908348351" itemprop="mainEntityOfPage" itemscope="" itemtype="https://schema.org/WebPage"></span>
# <span itemprop="author" itemscope="itemscope" itemtype="https://schema.org/Person">
# <span content="Anant Kaur" itemprop="name"></span>
# </span>
# <span content="Moeen Ali is on fire, he's enjoying batting at the top: Curran " itemprop="description"></span>
# <span itemprop="image" itemscope="" itemtype="https://schema.org/ImageObject">
# <meta content="https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2021/04_apr/20_tue/img_1618902249694_327.jpg?" itemprop="url"/>
# <meta content="864" itemprop="width"/>
# <meta content="483" itemprop="height"/>
# </span>
# <span itemprop="publisher" itemscope="itemscope" itemtype="https://schema.org/Organization">
# <span content="https://inshorts.com/" itemprop="url"></span>
# <span content="Inshorts" itemprop="name"></span>
# <span itemprop="logo" itemscope="" itemtype="https://schema.org/ImageObject">
# <span content="https://assets.inshorts.com/inshorts/images/v1/variants/jpg/m/2018/11_nov/21_wed/img_1542823931298_497.jpg" itemprop="url"></span>
# <meta content="400" itemprop="width"/>
# <meta content="60" itemprop="height"/>
# </span>
# </span>
# <div class="news-card-image" style="background-image: url('https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2021/04_apr/20_tue/img_1618902249694_327.jpg?')">
# </div>
# <div class="news-card-title news-right-box">
# <a class="clickable" href="/en/news/moeen-ali-is-on-fire-hes-enjoying-batting-at-the-top-curran-1618908348351" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'TitleOfNews', 'eventAction': 'clicked', 'eventLabel': 'Moeen%20Ali%20is%20on%20fire%2C%20he's%20enjoying%20batting%20at%20the%20top%3A%20Curran%20)' });" style="color:#44444d!important">
# <span itemprop="headline">Moeen Ali is on fire, he's enjoying batting at the top: Curran </span>
# </a>
# <div class="news-card-author-time news-card-author-time-in-title">
# <a href="/prev/en/news/moeen-ali-is-on-fire-hes-enjoying-batting-at-the-top-curran-1618908348351"><span class="short">short</span></a> by <span class="author">Anant Kaur</span> /
#       <span class="time" content="2021-04-20T08:45:48.000Z" itemprop="datePublished">02:15 pm</span> on <span clas="date">20 Apr 2021,Tuesday</span>
# </div>
# </div>
# <div class="news-card-content news-right-box">
# <div itemprop="articleBody">Chennai Super Kings all-rounder Sam Curran said that his teammate Moeen Ali is "on fire as he is really enjoying batting at the top" for the team in the ongoing IPL. All-rounder Ali batted at number three in the last two matches. Ali scored 26 runs and took three wickets in his side's 45-run victory against Rajasthan Royals on Monday.</div>
# <div class="news-card-author-time news-card-author-time-in-content">
# <a href="/prev/en/news/moeen-ali-is-on-fire-hes-enjoying-batting-at-the-top-curran-1618908348351"><span class="short">short</span></a> by <span class="author">Anant Kaur</span> /
#       <span class="time" content="2021-04-20T08:45:48.000Z" itemprop="dateModified">02:15 pm</span> on <span class="date">20 Apr</span>
# </div>
# </div>
# <div class="news-card-footer news-right-box">
# <div class="read-more">read more at <a class="source" href="https://aninews.in/news/sports/cricket/moeen-is-on-fire-hes-enjoying-batting-at-the-top-sam-curran20210420091448/?utm_campaign=fullarticle&amp;utm_medium=referral&amp;utm_source=inshorts " onclick="ga('send', {'hitType': 'event', 'eventCategory': 'ReadMore', 'eventAction': 'clicked', 'eventLabel': 'ANI%20News' });" target="_blank">ANI News</a></div>
# </div>
# </div>
# </div>
# <div class="">
# <div class="news-card z-depth-1" itemscope="" itemtype="http://schema.org/NewsArticle">
# <span content="" itemid="https://inshorts.com/en/news/csk-can-build-their-team-around-jadeja-once-dhoni-retires-vaughan-1618915574218" itemprop="mainEntityOfPage" itemscope="" itemtype="https://schema.org/WebPage"></span>
# <span itemprop="author" itemscope="itemscope" itemtype="https://schema.org/Person">
# <span content="Sumit Josh" itemprop="name"></span>
# </span>
# <span content="CSK can build their team around Jadeja once Dhoni retires: Vaughan" itemprop="description"></span>
# <span itemprop="image" itemscope="" itemtype="https://schema.org/ImageObject">
# <meta content="https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2021/04_apr/20_tue/img_1618913301221_89.jpg?" itemprop="url"/>
# <meta content="864" itemprop="width"/>
# <meta content="483" itemprop="height"/>
# </span>
# <span itemprop="publisher" itemscope="itemscope" itemtype="https://schema.org/Organization">
# <span content="https://inshorts.com/" itemprop="url"></span>
# <span content="Inshorts" itemprop="name"></span>
# <span itemprop="logo" itemscope="" itemtype="https://schema.org/ImageObject">
# <span content="https://assets.inshorts.com/inshorts/images/v1/variants/jpg/m/2018/11_nov/21_wed/img_1542823931298_497.jpg" itemprop="url"></span>
# <meta content="400" itemprop="width"/>
# <meta content="60" itemprop="height"/>
# </span>
# </span>
# <div class="news-card-image" style="background-image: url('https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2021/04_apr/20_tue/img_1618913301221_89.jpg?')">
# </div>
# <div class="news-card-title news-right-box">
# <a class="clickable" href="/en/news/csk-can-build-their-team-around-jadeja-once-dhoni-retires-vaughan-1618915574218" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'TitleOfNews', 'eventAction': 'clicked', 'eventLabel': 'CSK%20can%20build%20their%20team%20around%20Jadeja%20once%20Dhoni%20retires%3A%20Vaughan)' });" style="color:#44444d!important">
# <span itemprop="headline">CSK can build their team around Jadeja once Dhoni retires: Vaughan</span>
# </a>
# <div class="news-card-author-time news-card-author-time-in-title">
# <a href="/prev/en/news/csk-can-build-their-team-around-jadeja-once-dhoni-retires-vaughan-1618915574218"><span class="short">short</span></a> by <span class="author">Sumit Josh</span> /
#       <span class="time" content="2021-04-20T10:46:14.000Z" itemprop="datePublished">04:16 pm</span> on <span clas="date">20 Apr 2021,Tuesday</span>
# </div>
# </div>
# <div class="news-card-content news-right-box">
# <div itemprop="articleBody">Former England captain Michael Vaughan said all-rounder Ravindra Jadeja should succeed MS Dhoni as captain of CSK when the latter decides to retire from IPL. "Jadeja is the kind of cricketer that I would build my team around...He's that good with the ball, in the field, with the bat in hand, his mindset, his mentality is very good," Vaughan added</div>
# <div class="news-card-author-time news-card-author-time-in-content">
# <a href="/prev/en/news/csk-can-build-their-team-around-jadeja-once-dhoni-retires-vaughan-1618915574218"><span class="short">short</span></a> by <span class="author">Sumit Josh</span> /
# ...
# <span itemprop="headline">Dhawan looks solid even while playing fearless cricket: Kaif</span>
# </a>
# <div class="news-card-author-time news-card-author-time-in-title">
# <a href="/prev/en/news/dhawan-looks-solid-even-while-playing-fearless-cricket-kaif-1618843779051"><span class="short">short</span></a> by <span class="author">Ankur Taliyan</span> /
#       <span class="time" content="2021-04-19T14:49:39.000Z" itemprop="datePublished">08:19 pm</span> on <span clas="date">19 Apr 2021,Monday</span>
# </div>
# </div>
# <div class="news-card-content news-right-box">
# <div itemprop="articleBody">DC assistant coach Mohammad Kaif has praised Shikhar Dhawan, who has scored 85 and 92 in two of his three IPL matches, for his fearless batting. "Dhawan...looks solid even while playing fearless cricket. Cutting risks without compromising the strike rate is the mark of a great T20 batsman," Kaif tweeted. DC have won both matches when Dhawan crossed 50-run mark.</div>
# <div class="news-card-author-time news-card-author-time-in-content">
# <a href="/prev/en/news/dhawan-looks-solid-even-while-playing-fearless-cricket-kaif-1618843779051"><span class="short">short</span></a> by <span class="author">Ankur Taliyan</span> /
#       <span class="time" content="2021-04-19T14:49:39.000Z" itemprop="dateModified">08:19 pm</span> on <span class="date">19 Apr</span>
# </div>
# </div>
# <div class="news-card-footer news-right-box">
# <div class="read-more">read more at <a class="source" href="https://www.aninews.in/news/sports/cricket/ipl-2021-dhawan-is-the-rare-batsman-who-looks-solid-even-while-playing-fearless-cricket-says-kaif20210419185534/?utm_campaign=fullarticle&amp;utm_medium=referral&amp;utm_source=inshorts " onclick="ga('send', {'hitType': 'event', 'eventCategory': 'ReadMore', 'eventAction': 'clicked', 'eventLabel': 'ANI' });" target="_blank">ANI</a></div>
# </div>
# </div>
# </div>
# <div class="">
# <div class="news-card z-depth-1" itemscope="" itemtype="http://schema.org/NewsArticle">
# <span content="" itemid="https://inshorts.com/en/news/wtc-final-to-go-ahead-in-june-icc-after-britain-adds-india-to-travel-red-list-1618898462512" itemprop="mainEntityOfPage" itemscope="" itemtype="https://schema.org/WebPage"></span>
# <span itemprop="author" itemscope="itemscope" itemtype="https://schema.org/Person">
# <span content="Anant Kaur" itemprop="name"></span>
# </span>
# <span content="WTC final to go ahead in June: ICC after Britain adds India to travel red list" itemprop="description"></span>
# <span itemprop="image" itemscope="" itemtype="https://schema.org/ImageObject">
# <meta content="https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2021/04_apr/20_tue/img_1618897772578_784.jpg?" itemprop="url"/>
# <meta content="864" itemprop="width"/>
# <meta content="483" itemprop="height"/>
# </span>
# <span itemprop="publisher" itemscope="itemscope" itemtype="https://schema.org/Organization">
# <span content="https://inshorts.com/" itemprop="url"></span>
# <span content="Inshorts" itemprop="name"></span>
# <span itemprop="logo" itemscope="" itemtype="https://schema.org/ImageObject">
# <span content="https://assets.inshorts.com/inshorts/images/v1/variants/jpg/m/2018/11_nov/21_wed/img_1542823931298_497.jpg" itemprop="url"></span>
# <meta content="400" itemprop="width"/>
# <meta content="60" itemprop="height"/>
# </span>
# </span>
# <div class="news-card-image" style="background-image: url('https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2021/04_apr/20_tue/img_1618897772578_784.jpg?')">
# </div>
# <div class="news-card-title news-right-box">
# <a class="clickable" href="/en/news/wtc-final-to-go-ahead-in-june-icc-after-britain-adds-india-to-travel-red-list-1618898462512" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'TitleOfNews', 'eventAction': 'clicked', 'eventLabel': 'WTC%20final%20to%20go%20ahead%20in%20June%3A%20ICC%20after%20Britain%20adds%20India%20to%20travel%20red%20list)' });" style="color:#44444d!important">
# <span itemprop="headline">WTC final to go ahead in June: ICC after Britain adds India to travel red list</span>
# </a>
# <div class="news-card-author-time news-card-author-time-in-title">
# <a href="/prev/en/news/wtc-final-to-go-ahead-in-june-icc-after-britain-adds-india-to-travel-red-list-1618898462512"><span class="short">short</span></a> by <span class="author">Anant Kaur</span> /
#       <span class="time" content="2021-04-20T06:01:02.000Z" itemprop="datePublished">11:31 am</span> on <span clas="date">20 Apr 2021,Tuesday</span>
# </div>
# </div>
# <div class="news-card-content news-right-box">
# <div itemprop="articleBody">The ICC on Monday said that the World Test Championship (WTC) final between India and New Zealand in Southampton from June 18 will go ahead as planned despite Britain adding India to the travel 'red list'. Britain cancelled arrivals from India after COVID-19 surge in the country. The final will be played in bio-secure bubble at Hampshire Bowl in Southampton.</div>
# <div class="news-card-author-time news-card-author-time-in-content">
# <a href="/prev/en/news/wtc-final-to-go-ahead-in-june-icc-after-britain-adds-india-to-travel-red-list-1618898462512"><span class="short">short</span></a> by <span class="author">Anant Kaur</span> /
#       <span class="time" content="2021-04-20T06:01:02.000Z" itemprop="dateModified">11:31 am</span> on <span class="date">20 Apr</span>
# </div>
# </div>
# <div class="news-card-footer news-right-box">
# <div class="read-more">read more at <a class="source" href="https://aninews.in/news/sports/cricket/covid-19-icc-confident-wtc-final-will-go-ahead-as-planned-in-june-in-uk20210419231639/?utm_campaign=fullarticle&amp;utm_medium=referral&amp;utm_source=inshorts " onclick="ga('send', {'hitType': 'event', 'eventCategory': 'ReadMore', 'eventAction': 'clicked', 'eventLabel': 'ANI%20News' });" target="_blank">ANI News</a></div>
# </div>
# </div>
# </div>
# <div class="">
# <div class="news-card z-depth-1" itemscope="" itemtype="http://schema.org/NewsArticle">
# <span content="" itemid="https://inshorts.com/en/news/thank-you-boss-pleasure-to-work-together-harry-kane-to-mourinho-1618896466787" itemprop="mainEntityOfPage" itemscope="" itemtype="https://schema.org/WebPage"></span>
# <span itemprop="author" itemscope="itemscope" itemtype="https://schema.org/Person">
# <span content="Sumit Josh" itemprop="name"></span>
# </span>
# <span content="Thank you Boss, pleasure to work together: Harry Kane to Mourinho" itemprop="description"></span>
# <span itemprop="image" itemscope="" itemtype="https://schema.org/ImageObject">
# <meta content="https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2021/04_apr/20_tue/img_1618894324187_231.jpg?" itemprop="url"/>
# <meta content="864" itemprop="width"/>
# <meta content="483" itemprop="height"/>
# </span>
# <span itemprop="publisher" itemscope="itemscope" itemtype="https://schema.org/Organization">
# <span content="https://inshorts.com/" itemprop="url"></span>
# <span content="Inshorts" itemprop="name"></span>
# <span itemprop="logo" itemscope="" itemtype="https://schema.org/ImageObject">
# <span content="https://assets.inshorts.com/inshorts/images/v1/variants/jpg/m/2018/11_nov/21_wed/img_1542823931298_497.jpg" itemprop="url"></span>
# <meta content="400" itemprop="width"/>
# <meta content="60" itemprop="height"/>
# </span>
# </span>
# <div class="news-card-image" style="background-image: url('https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2021/04_apr/20_tue/img_1618894324187_231.jpg?')">
# </div>
# <div class="news-card-title news-right-box">
# <a class="clickable" href="/en/news/thank-you-boss-pleasure-to-work-together-harry-kane-to-mourinho-1618896466787" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'TitleOfNews', 'eventAction': 'clicked', 'eventLabel': 'Thank%20you%20Boss%2C%20pleasure%20to%20work%20together%3A%20Harry%20Kane%20to%20Mourinho)' });" style="color:#44444d!important">
# <span itemprop="headline">Thank you Boss, pleasure to work together: Harry Kane to Mourinho</span>
# </a>
# <div class="news-card-author-time news-card-author-time-in-title">
# <a href="/prev/en/news/thank-you-boss-pleasure-to-work-together-harry-kane-to-mourinho-1618896466787"><span class="short">short</span></a> by <span class="author">Sumit Josh</span> /
#       <span class="time" content="2021-04-20T05:27:46.000Z" itemprop="datePublished">10:57 am</span> on <span clas="date">20 Apr 2021,Tuesday</span>
# </div>
# </div>
# <div class="news-card-content news-right-box">
# <div itemprop="articleBody">Tottenham Hotspur striker Harry Kane has thanked outgoing manager Jose Mourinho and said it was a pleasure to work together with him. "Thank you for everything Boss...I wish you all the best for your next chapter," Kane tweeted. Tottenham sacked Mourinho and his coaching staff on Monday ahead of the Carabao Cup final against Manchester City.</div>
# <div class="news-card-author-time news-card-author-time-in-content">
# <a href="/prev/en/news/thank-you-boss-pleasure-to-work-together-harry-kane-to-mourinho-1618896466787"><span class="short">short</span></a> by <span class="author">Sumit Josh</span> /
#       <span class="time" content="2021-04-20T05:27:46.000Z" itemprop="dateModified">10:57 am</span> on <span class="date">20 Apr</span>
# </div>
# </div>
# <div class="news-card-footer news-right-box">
# <div class="read-more">read more at <a class="source" href="https://aninews.in/news/sports/football/pleasure-to-have-worked-together-kane-to-mourinho20210419205937/?utm_campaign=fullarticle&amp;utm_medium=referral&amp;utm_source=inshorts " onclick="ga('send', {'hitType': 'event', 'eventCategory': 'ReadMore', 'eventAction': 'clicked', 'eventLabel': 'ANI' });" target="_blank">ANI</a></div>
# </div>
# </div>
# </div>
# </div>
# <div class="load-more-wrapper">
# <div class="clickable unselectable load-more z-depth-1 hoverable" id="load-more-btn" onclick="loadMoreNews()">Load More</div>
# <div class="clickable unselectable load-more" id="load-more-gif" style="display:none;"><img id="load-more-gif" src="https://assets.inshorts.com/website_assets/images/ajax-loader.gif"/></div>
# </div>
# <div class="my-red app-download-pane hide-on-large-only">
# <div class="container">
# <div class="row">
# <div class="col s12 center" style="color:white;font-weight: 300;font-size:14px;margin-top: 28px;margin-bottom: 18px;">
#               For the best experience use <a href="/mobile" style="color:white;appearance: none;font-weight: 500;" target="_blank">inshorts</a> app on your smartphone
#             </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <!-- BODY END -->
# <footer class="page-footer teals">
# <div class="container">
# <div class="row" style="margin-bottom: 0px; padding-bottom: 5px;">
# <div class="col offset-l3 l3 m4 s12 right social-admin">
# <div class="social-share"><a href="https://www.facebook.com/inshortsapp" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'LinkToFaceBookPage', 'eventAction': 'clicked', 'eventLabel': 'RedirectedToFaceBook' });" target="_blank"><img src="https://assets.inshorts.com/website_assets/images/facebook.png"/></a></div>
# <div class="social-share"><a href="https://twitter.com/inshorts" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'LinkToTwitterPage', 'eventAction': 'clicked', 'eventLabel': 'RedirectedToTwitter' });" target="_blank"><img src="https://assets.inshorts.com/website_assets/images/twitter.png"/></a></div>
# <div class="social-share"><a href="https://www.linkedin.com/company/news-in-shorts" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'LinkToLinkedinPage', 'eventAction': 'clicked', 'eventLabel': 'RedirectedToLinkedin' });" target="_blank"><img src="https://assets.inshorts.com/website_assets/images/linkedin.png"/></a></div>
# </div>
# <div class="col m4 l3 s6 footer-left-pane">
# <div class="right"><img height="48px" src="https://assets.inshorts.com/website_assets/images/logo_footer.png" width="160px"/></div>
# <div class="copy-text">
# <span><span style="color:#cfcfcf;font-family: 'Conv_ClanPro-Bold'">inshorts</span> medialabs pvt. ltd.</span><br/>
#           ©<span style="font-size:12px">COPYRIGHT 2021</span>
# </div>
# </div>
# <div class="col m4 l3 s6 footer-right-pane">
# <div class="left clickable" id="contactUsBtn" style="margin-top: -5px;"><img height="48px" src="https://assets.inshorts.com/website_assets/images/contact_icon.png" width="132px"/></div>
# <div class="terms-text">
# <a class="tnc" href="/tnc" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'LinkToTermsAndConditionsAndPP', 'eventAction': 'clicked', 'eventLabel': 'RedirectedToTermsAndConditions' });" style="color: #fff;" target="_blank"><span>Terms &amp; conditions</span><br/>
# <span>Privacy Policies</span>
# </a>
# <br/>
# <a class="tnc" href="/editorial_policy" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'LinkToSitemap', 'eventAction': 'clicked', 'eventLabel': 'RedirectedToSitemap' });" style="color: #fff;" target="_blank">
# <span>Editorial Policy</span>
# </a>
# </div>
# </div>
# </div>
# </div>
# <div class="modal_contact row" id="contactUsModal">
# <!-- Modal content -->
# <div class="modal-content col l4 m4 s8 offset-s2 offset-l4 offset-m4">
# <span class="close">×</span>
# <div class="contact">
# <a href="mailto:careers@inshorts.com?subject=Inshorts%20website%20contact%20form" target="_blank">
# <button id="myBtn">Contact Hiring Team</button>
# </a>
# </div>
# <div class="contact">
# <a href="mailto:Admin@inshorts.com?subject=Inshorts%20website%20contact%20form" target="_blank">
# <button id="myBtn">Contact Admin Team</button>
# </a>
# </div>
# <div class="contact">
# <a href="mailto:Marketing@inshorts.com?subject=Inshorts%20website%20contact%20form" target="_blank">
# <button id="myBtn">Contact Marketing Team</button>
# </a>
# </div>
# <div class="contact">
# <a href="mailto:Editorial@inshorts.com?subject=Inshorts%20website%20contact%20form" target="_blank">
# <button id="myBtn">Contact Editorial Team</button>
# </a>
# </div>
# <div class="contact">
# <a href="mailto:Sales@inshorts.com?subject=Inshorts%20website%20contact%20form" target="_blank">
# <button id="myBtn">Contact Sales Team</button>
# </a>
# </div>
# <div class="contact">
# <a href="mailto:Contact@inshorts.com?subject=Inshorts%20website%20contact%20form" target="_blank">
# <button id="myBtn">Contact For Any Other Query</button>
# </a>
# </div>
# </div>
# </div>
# </footer>
# <script>
# var modal = document.getElementById('contactUsModal');
#
# // Get the button that opens the modal
# var btn = document.getElementById("contactUsBtn");
#
# // Get the <span> element that closes the modal
# var span = document.getElementsByClassName("close")[0];
#
# // When the user clicks on the button, open the modal
# btn.onclick = function() {
#     modal.style.display = "block";
# }
#
# // When the user clicks on <span> (x), close the modal
# span.onclick = function() {
#     modal.style.display = "none";
# }
#
# // When the user clicks anywhere outside of the modal, close it
# window.onclick = function(event) {
#     if (event.target == modal) {
#         modal.style.display = "none";
#     }
# }
# </script>
# <!-- Eliminate render-blocking JavaScript and CSS in above-the-fold content -->
# <script src="https://ajax.googleapis.com/ajax/libs/jquery/1.8/jquery.min.js"></script>
# <script src="https://cdnjs.cloudflare.com/ajax/libs/materialize/0.97.0/js/materialize.min.js"></script>
# <script src="/dist/scripts/index.js" type="text/javascript"></script>
# <script src="/dist/scripts/read.js" type="text/javascript"></script>
# <script src="/dist/scripts/jquery.scrolldepth.min.js"></script>
# <script type="text/javascript">
#
#     var min_news_id = "ywru7ku2-1";
#     function loadMoreNews(){
#       $("#load-more-btn").hide();
#       $("#load-more-gif").show();
#       $.post("/en/ajax/more_news",{'category':'sports','news_offset':min_news_id},function(data){
#           data = JSON.parse(data);
#           min_news_id = data.min_news_id||min_news_id;
#           $(".card-stack").append(data.html);
#       })
#       .fail(function(){alert("Error : unable to load more news");})
#       .always(function(){$("#load-more-btn").show();$("#load-more-gif").hide();});
#     }
#     jQuery.scrollDepth();
#   </script>
# <!-- Eliminate render-blocking JavaScript and CSS in above-the-fold content -->
# </body>
# </html>

# %%
urls = ['https://inshorts.com/en/read/sports',
        'https://inshorts.com/en/read',
        'https://inshorts.com/en/read/technology']

def build_dataset(urls):
  news_data = []
  for url in urls:
    news_category = url.split('/')[-1]
    data = requests.get(url)
    soup = BeautifulSoup(data.content)

    news_articles = [{'news_headline':headline.find('span',attrs={"itemprop":"headline"}).string,
                      'news_article':article.find('div',attrs={"itemprop":"articleBody"}).string,
                      'news_category':news_category}
                        
                    for headline,article in zip(soup.find_all('div',class_=["news-card-title news-right-box"]),
                                                soup.find_all('div',class_=["news-card-content news-right-box"]))]
    news_articles = news_articles[0:20]
    news_data.extend(news_articles)

  df = pd.DataFrame(news_data)
  df = df[['news_headline','news_article','news_category']]
  return df

# %%
df = build_dataset(urls)
df.head()
# Out:
#                                        news_headline  ... news_category
# 0  Ravindra Jadeja's 'call me' celebration after ...  ...        sports
# 1  Picture of Dwayne Bravo 'stealing' a run goes ...  ...        sports
# 2  SL's Lokuhettige banned for 8 years for match-...  ...        sports
# 3  Can't guarantee performances at 40 but don't w...  ...        sports
# 4  CSK mark Dhoni's 200th match as their captain ...  ...        sports
#
# [5 rows x 3 columns]

# %%
df = build_dataset(urls)
df.tail()
# Out:
#                                         news_headline  ... news_category
# 55  Our staff can continue working remotely after ...  ...    technology
# 56  Dogecoin supply & demand undefeated, will find...  ...    technology
# 57  Zoom launches $100M fund for startups using it...  ...    technology
# 58  James Charles' YouTube channel demonetised ove...  ...    technology
# 59  Dogecoin trades at 42 cents as Twitter users p...  ...    technology
#
# [5 rows x 3 columns]

# %%
a=[1,2,3,4]
for i in a:
  print(i)
# Out:
# 1
# 2
# 3
# 4

# %%
a=[1,2,3,4]
for i in a:
  print(i)
# Out:
# 1
# 2
# 3
# 4

# %%
# df=build_dataset(urls)
# df.tail()

# %%
df.to_csv("news.csv",index=False)

# %%
import pandas as pd
df=pd.read_csv('https://raw.githubusercontent.com/Phani-0808/Major-/main/news.csv')
df
# Out:
#                                         news_headline  ... news_category
# 0   Andre Russell records best bowling figures for...  ...        sports
# 1   New name, new jersey, still Sadda Punjab won't...  ...        sports
# 2   Bhuvneshwar marks return to int'l cricket with...  ...        sports
# 3   Rajasthan Royals' Riyan Parag tweets 'I am shi...  ...        sports
# 4   Rohit Sharma's fans call for boycott of Swiggy...  ...        sports
# 5   Latest rankings for ODI batsmen out, Babar ove...  ...        sports
# 6   Hiren got no chill: Sehwag as MI fan asks Maha...  ...        sports
# 7   MI record their 1st win of IPL 2021, beat KKR ...  ...        sports
# 8   Shah Rukh Khan calls KKR's performance vs MI d...  ...        sports
# 9   Andre Russell responds to SRK's apology tweet,...  ...        sports
# 10  Suryakumar Yadav smashes 99-metre six against ...  ...        sports
# 11  Chris Morris' reaction after being denied a si...  ...        sports
# 12  Ben Stokes breaks finger while taking catch of...  ...        sports
# 13  IPL final win against Pune in 2017 my favourit...  ...        sports
# 14  Gayle has more sixes but I've more fours than ...  ...        sports
# 15  Enjoyed Tripathi's dismissal most, ideal leg-s...  ...        sports
# 16  Wanted to bowl during death overs for a long t...  ...        sports
# 17  Not much depth in SRH compared to other IPL te...  ...        sports
# 18  Disappointing, not sure what happened: Morgan ...  ...        sports
# 19  Felt insulted when people didn't show interest...  ...        sports
# 20  CBSE Class 12 board exams postponed, Class 10 ...  ...          read
# 21  Kolkata airport makes -ve Covid-19 report mand...  ...          read
# 22  Govt releases list of 16 states showing upward...  ...          read
# 23  Which states/UTs did not report any COVID-19 d...  ...          read
# 24  Which states reported the most number of death...  ...          read
# 25  UP CM orders to get 25,000 Remdesivir injectio...  ...          read
# 26  Instead of 15L vaccine doses Centre sent 4L: P...  ...          read
# 27  Which 10 states reported 82.04% of the new cor...  ...          read
# 28  Latest rankings for ODI batsmen out, Babar ove...  ...          read
# 29  Dogecoin surpasses 10 cents for the 1st time, ...  ...          read
# 30  Mamata meets Cooch Behar victims' families aft...  ...          read
# 31  Star & Disney India Country Manager K Madhavan...  ...          read
# 32  Security checked my pulse to ensure I'm alive:...  ...          read
# 33  Dogs will keep barking: Vahbiz on trolls body ...  ...          read
# 34  It's the most fulfilling experience: Katy Perr...  ...          read
# 35  Enjoyed Tripathi's dismissal most, ideal leg-s...  ...          read
# 36  Incompetence of PM Modi leading to rising COVI...  ...          read
# 37  Not much depth in SRH compared to other IPL te...  ...          read
# 38   Bitcoin breaches $64,000-mark for the first time  ...          read
# 39  Rahul tweets as govt fast-tracks foreign vacci...  ...          read
# 40  Vivo phones banned by Hong Kong-based cargo ai...  ...    technology
# 41  WhatsApp flaw lets anyone deactivate accounts ...  ...    technology
# 42  Toshiba CEO steps down amid turmoil over buyou...  ...    technology
# 43  Jack Ma's fortune jumps $2.3 billion after rec...  ...    technology
# 44  Dogecoin surpasses 10 cents for the 1st time, ...  ...    technology
# 45  Siri reveals Apple's next event is planned for...  ...    technology
# 46  Facebook is testing video speed-dating app cal...  ...    technology
# 47  NYSE launches 'First Trade' NFTs of 6 firms th...  ...    technology
# 48  Sad to see a friend leaving: Korean man who co...  ...    technology
# 49   Bitcoin breaches $64,000-mark for the first time  ...    technology
# 50  Intel in talks to make chips for automakers wi...  ...    technology
# 51  AFMC, NIMHANS launch mobile app for mental wel...  ...    technology
# 52  Bill to ban acquisitions by Google, Amazon, ot...  ...    technology
# 53  Facebook shuts down page of French town 'Bitch...  ...    technology
# 54  WhatsApp policy would lead to excessive data c...  ...    technology
# 55  Data collected by us in China will be stored i...  ...    technology
# 56              Bitcoin hits all time high of $62,741  ...    technology
# 57  Global PC shipments grew 32% y-o-y in Q1 of 20...  ...    technology
# 58  Auction house Sotheby's sells NFT works by dig...  ...    technology
# 59  Central bank digital currencies do not threate...  ...    technology
#
# [60 rows x 3 columns]

# %%
# natural language tool kit
import nltk
nltk.download('stopwords')
stopword_list = nltk.corpus.stopwords.words('english')
# len(stopword_list)
stopword_list.remove('no')
stopword_list.remove('not')
len(stopword_list)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# 177

# %%
# remove HTML Tag
def html_tag(text):
  soup = BeautifulSoup(text,"html.parser")
  new_text = soup.get_text()
  return new_text

html_tag('<html><h2>Some important info <h2><html>')
# Out:
# 'Some important info '

# %%
# Expand Contractions
# !pip install contractions
import contractions
def con(text):
  expand = contractions.fix(text)
  return expand

con("Y'all can't expand I'd think")
# Out:
# Collecting contractions
#   Downloading https://files.pythonhosted.org/packages/0a/04/d5e0bb9f2cef5d15616ebf68087a725c5dbdd71bd422bcfb35d709f98ce7/contractions-0.0.48-py2.py3-none-any.whl
# Collecting textsearch>=0.0.21
#   Downloading https://files.pythonhosted.org/packages/d3/fe/021d7d76961b5ceb9f8d022c4138461d83beff36c3938dc424586085e559/textsearch-0.0.21-py2.py3-none-any.whl
# Collecting anyascii
#   Downloading https://files.pythonhosted.org/packages/a3/14/666cd44bf53f36a961544af592cb5c5c800013f9c51a4745af8d7c17362a/anyascii-0.2.0-py3-none-any.whl (283kB)
#      |████████████████████████████████| 286kB 6.8MB/s
# Collecting pyahocorasick
#   Downloading https://files.pythonhosted.org/packages/7f/c2/eae730037ae1cbbfaa229d27030d1d5e34a1e41114b21447d1202ae9c220/pyahocorasick-1.4.2.tar.gz (321kB)
#      |████████████████████████████████| 327kB 7.2MB/s
# Building wheels for collected packages: pyahocorasick
#   Building wheel for pyahocorasick (setup.py) ... done
#   Created wheel for pyahocorasick: filename=pyahocorasick-1.4.2-cp37-cp37m-linux_x86_64.whl size=85395 sha256=dae407bf64aca8f2e1ea79d675bab8eee22a1c204811cf9705e5132d536ebcfd
#   Stored in directory: /root/.cache/pip/wheels/3a/03/34/77e3ece0bba8b86bfac88a79f923b36d805cad63caeba38842
# Successfully built pyahocorasick
# Installing collected packages: anyascii, pyahocorasick, textsearch, contractions
# Successfully installed anyascii-0.2.0 contractions-0.0.48 pyahocorasick-1.4.2 textsearch-0.0.21
# 'you all can not expand I would think'

# %%
# Special characters
import re
def remove_sp(text):
  pattern = r'[^A-Za-z0-9\s ]'
  text =re.sub(pattern,'',text)
  return text

remove_sp("??+-*Phani")
# Out:
# 'Phani'

# %%
from nltk.tokenize.toktok import ToktokTokenizer
tokenizer = ToktokTokenizer()

# %%
def remove_stopwords(text):
  tokens = tokenizer.tokenize(text)
  tokens = [token.strip() for token in tokens]
  filtered_tokens = [token for token in tokens if token not in stopword_list]
  filtered_text = ' '.join(filtered_tokens)
  return filtered_text

# %%
remove_stopwords("The, and , if are all stopwords and even not ")
# Out:
# 'The , , stopwords even not'

# %%
# 1. Lower case
# 2. HTMP Tags
# 3. Contractions
# 4. Special characters
# 5. Stop words 
df.news_headlines = df.news_headline.apply(lambda x:x.lower())
df.news_article = df.news_article.apply(lambda x:x.lower())

df.news_headline = df.news_headline.apply(html_tag)
df.news_article = df.news_article.apply(html_tag)

df.news_headline = df.news_headline.apply(con)
df.news_article = df.news_article.apply(con)

df.news_headline = df.news_headline.apply(remove_sp)
df.news_article = df.news_article.apply(remove_sp)

df.news_headline = df.news_headline.apply(remove_stopwords)
df.news_article = df.news_article.apply(remove_stopwords)


df.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#                                        news_headline  ... news_category
# 0  Andre Russell records best bowling figures KKR...  ...        sports
# 1  New name new jersey still Sadda Punjab not sto...  ...        sports
# 2  Bhuvneshwar marks return intl cricket ICC Play...  ...        sports
# 3  Rajasthan Royals Riyan Parag tweets I shit tea...  ...        sports
# 4  Rohit Sharmas fans call boycott Swiggy mocking...  ...        sports
#
# [5 rows x 3 columns]

# %%
df['compound'] = df['news_article'].apply(lambda x: vs.polarity_scores(x)['compound'])

# %%
df.head()
# Out:
#                                        news_headline  ... compound
# 0  Andre Russell records best bowling figures KKR...  ...   0.8555
# 1  New name new jersey still Sadda Punjab not sto...  ...   0.7687
# 2  Bhuvneshwar marks return intl cricket ICC Play...  ...   0.5302
# 3  Rajasthan Royals Riyan Parag tweets I shit tea...  ...  -0.5994
# 4  Rohit Sharmas fans call boycott Swiggy mocking...  ...  -0.6717
#
# [5 rows x 4 columns]

# %%
import pandas as pd
# !pip install -q wordcloud
import wordcloud
import nltk
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# True

# %%
df = pd.read_csv('https://raw.githubusercontent.com/Phani-0808/Major-/main/Review_data.csv')
df
# Out:
#                                                  review  rating
# 0     It was nice produt. I like it's design a lot. ...       5
# 1     awesome sound....very pretty to see this nd th...       5
# 2     awesome sound quality. pros 7-8 hrs of battery...       4
# 3     I think it is such a good product not only as ...       5
# 4     awesome bass sound quality very good bettary l...       5
# ...                                                 ...     ...
# 9971                                      GoodREAD MORE       5
# 9972  Everything is amazimg but the built is very li...       5
# 9973                                      GoodREAD MORE       5
# 9974       Best headphone i have ever used....READ MORE       5
# 9975                                      NiceREAD MORE       5
#
# [9976 rows x 2 columns]

# %%
df['rating'] = df['rating'].replace(5,'Good')
df['rating'] = df['rating'].replace(4,'Good')
df['rating'] = df['rating'].replace(3,'Good')
df['rating'] = df['rating'].replace(2,'Bad')
df['rating'] = df['rating'].replace(1,'Bad')

# %%
#preprocess data
df['review'] = df['review'].str.lower()  #Convert to lower case
df['review'] = df['review'].str.replace('\d+', '') #removing numbers
df['review'] = df['review'].str.replace('.','')
df['review'] = df['review'].str.replace('-','')
df['review'] = df['review'].str.replace('?','')
df['review'] = df['review'].str.replace("'",'')
df['review'] = df['review'].str.replace('  ','')  #for extra spaces

# %%
#tokenization and stemming
from nltk.stem.snowball import SnowballStemmer
df['tokenized_sents'] = df.apply(lambda row: nltk.word_tokenize(row['review']), axis=1)
stemmer = SnowballStemmer("english")
df['stemmed'] = df['tokenized_sents'].apply(lambda x: [stemmer.stem(y) for y in x]) # Stem every word.
df = df.drop(columns=['tokenized_sents'])
df['review'] = df['stemmed'].apply(lambda x: ' '.join(map(str, x)))
df = df.drop(columns=['stemmed'])

# %%
x = df.iloc[:,0]
y = df.iloc[:,1]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,random_state=0,stratify=y)

# %%
#Vectorization and model fitting using pipeline
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.svm import SVC
text_model = Pipeline([('tfidi',TfidfVectorizer()),('model',SVC())])
text_model.fit(x_train,y_train)
# Out:
# Pipeline(memory=None,
#          steps=[('tfidi',
#                  TfidfVectorizer(analyzer='word', binary=False,
#                                  decode_error='strict',
#                                  dtype=<class 'numpy.float64'>,
#                                  encoding='utf-8', input='content',
#                                  lowercase=True, max_df=1.0, max_features=None,
#                                  min_df=1, ngram_range=(1, 1), norm='l2',
#                                  preprocessor=None, smooth_idf=True,
#                                  stop_words=None, strip_accents=None,
#                                  sublinear_tf=False,
#                                  token_pattern='(?u)\\b\\w\\w+\\b',
#                                  tokenizer=None, use_idf=True,
#                                  vocabulary=None)),
#                 ('model',
#                  SVC(C=1.0, break_ties=False, cache_size=200, class_weight=None,
#                      coef0=0.0, decision_function_shape='ovr', degree=3,
#                      gamma='scale', kernel='rbf', max_iter=-1,
#                      probability=False, random_state=None, shrinking=True,
#                      tol=0.001, verbose=False))],
#          verbose=False)

# %%
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score
y_pred = text_model.predict(x_test)
accuracy_score(y_test,y_pred)
# Out:
# 0.9370489174017642

# %%
#confusion matrix
confusion_matrix(y_test,y_pred)
# Out:
# array([[ 117,  133],
#        [  24, 2220]])

# %%
#Classification report
classification_report(y_test,y_pred)
# Out:
# '              precision    recall  f1-score   support\n\n         Bad       0.83      0.47      0.60       250\n        Good       0.94      0.99      0.97      2244\n\n    accuracy                           0.94      2494\n   macro avg       0.89      0.73      0.78      2494\nweighted avg       0.93      0.94      0.93      2494\n'

# %%
import joblib
joblib.dump(text_model,'Email_Class')
# Out:
# ['Email_Class']

# %%
# !pip install streamlit --quiet
# !pip install pyngrok==4.1.1 --quiet
from pyngrok import ngrok
# Out:
#      |████████████████████████████████| 8.2MB 6.2MB/s
#      |████████████████████████████████| 112kB 45.9MB/s
#      |████████████████████████████████| 4.2MB 40.3MB/s
#      |████████████████████████████████| 163kB 64.9MB/s
#      |████████████████████████████████| 81kB 10.2MB/s
#      |████████████████████████████████| 122kB 41.5MB/s
#      |████████████████████████████████| 71kB 10.2MB/s
#   Building wheel for blinker (setup.py) ... done
# ERROR: google-colab 1.0.0 has requirement ipykernel~=4.10, but you'll have ipykernel 5.5.3 which is incompatible.
#   Building wheel for pyngrok (setup.py) ... done

# %%
# %%writefile app.py
import streamlit as st
import sklearn
import joblib
model =joblib.load('Email_Class')

add_selectbox = st.sidebar.radio("Our page",['Home',"Rate us"])
if(add_selectbox == 'Home'):
  st.title("Myntra collections")
  st.image('https://akm-img-a-in.tosshub.com/sites/btmt/images/stories/myntra_logo_660_300121011207.jpg')

  ip = st.text_input('Enter your valuabe review')
  p = model.predict([ip])
  if st.button('Predict'):
    st.header(p[0])
    if(p[0]=='Good'):
      st.markdown(""":smile:""")
    else:
      st.markdown(""":angry:""")
else:
  st.title("Please Rate US")
  st.slider("Rate us",0,5)
  if st.button("Press Submit"):
    st.header("Thanks for your rating..")
# Out:
# Writing app.py

# %%
# !nohup streamlit run app.py&
url = ngrok.connect(port = '8501')
url
# Out:
# nohup: appending output to 'nohup.out'
# 'http://3ad83dd312f8.ngrok.io'

# %%
# !pip install pipreqs
# Out:
# Collecting pipreqs
#   Downloading https://files.pythonhosted.org/packages/9b/83/b1560948400a07ec094a15c2f64587b70e1a5ab5f7b375ba902fcab5b6c3/pipreqs-0.4.10-py2.py3-none-any.whl
# Requirement already satisfied: docopt in /usr/local/lib/python3.7/dist-packages (from pipreqs) (0.6.2)
# Collecting yarg
#   Downloading https://files.pythonhosted.org/packages/8b/90/89a2ff242ccab6a24fbab18dbbabc67c51a6f0ed01f9a0f41689dc177419/yarg-0.1.9-py2.py3-none-any.whl
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from yarg->pipreqs) (2.23.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->yarg->pipreqs) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->yarg->pipreqs) (2020.12.5)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->yarg->pipreqs) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->yarg->pipreqs) (2.10)
# Installing collected packages: yarg, pipreqs
# Successfully installed pipreqs-0.4.10 yarg-0.1.9

# %%
# !pipreqs /content
# Out:
# INFO: Successfully saved requirements file in /content/requirements.txt
